# %%
import pandas as pd
import os

# %%
# %pwd
# Out:
# '/Users/rahulshelke/Documents/Data-Science/Data-Science-Projects/heart-stroke-prediction/notebooks'

# %%
# os.chdir("../")

# %%
# %pwd
# Out:
# '/Users/rahulshelke/Documents/Data-Science/Data-Science-Projects/heart-stroke-prediction/notebooks'

# %%
df = pd.read_csv('data/healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'id': 9046,
#   'gender': 'Male',
#   'age': 67.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Urban',
#   'avg_glucose_level': 228.69,
#   'bmi': 36.6,
#   'smoking_status': 'formerly smoked',
#   'stroke': 1},
#  {'id': 51676,
#   'gender': 'Female',
#   'age': 61.0,
#   'hypertension': 0,
#   'heart_disease': 0,
#   'ever_married': 'Yes',
#   'work_type': 'Self-employed',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 202.21,
#   'bmi': nan,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 31112,
#   'gender': 'Male',
#   'age': 80.0,
#   'hypertension': 0,
#   'heart_disease': 1,
#   'ever_married': 'Yes',
#   'work_type': 'Private',
#   'Residence_type': 'Rural',
#   'avg_glucose_level': 105.92,
#   'bmi': 32.5,
#   'smoking_status': 'never smoked',
#   'stroke': 1},
#  {'id': 60182,
#   'gender': 'Female',
#   'age': 49.0,
#   'hypertension': 0,
#   'heart_disease': 0,
# ...

# %%
import pymongo

DB_NAME = "heart_stroke_db" # specifing a database name

# Connection URL
CONNECTION_URL = "mongodb+srv://rahulshelke:Rahul123@mlcluster.uhbxanv.mongodb.net/?retryWrites=true&w=majority&appName=mlcluster"

# Establish a connection with mongoDB
client = pymongo.MongoClient(CONNECTION_URL)

# create a db
databse = client[DB_NAME]

# create a collection name
COLLECTION_NAME = "heart_stroke"
collection = databse[COLLECTION_NAME]

# create a list of records
# list_of_records = [
#     {
#         'name': 'Alex',
#         'email': 'alex@gmail.com',
#         'phone': '9767985498',
#         'password': '7878hi'    
#     },

#     {
#         'name' : 'Ellen',
#         'email': 'ellen@gmail.com',
#         'phone': '9876549845',
#         'password': 
#     }
# ]

# %%
import pymongo

DB_NAME = "heart_stroke_db" # specifing a database name

# Connection URL
CONNECTION_URL = "mongodb+srv://rahulshelke:Rahul123@mlcluster.uhbxanv.mongodb.net/?retryWrites=true&w=majority&appName=mlcluster"

# Establish a connection with mongoDB
client = pymongo.MongoClient(CONNECTION_URL)

# create a db
databse = client[DB_NAME]

# create a collection name
COLLECTION_NAME = "heart_stroke"
collection = databse[COLLECTION_NAME]

# insert above records in the collection
rec = collection.insert_many(data)

# lets verify all the record at once present in the reocrd with all the fields
all_record = collection.find()

for idx, record in enumerate(all_record):
    print(f"{idx}: {record}")
# Out:
# 0: {'_id': ObjectId('68518bd98498f7c04663a43a'), 'id': 9046, 'gender': 'Male', 'age': 67.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Urban', 'avg_glucose_level': 228.69, 'bmi': 36.6, 'smoking_status': 'formerly smoked', 'stroke': 1}
# 1: {'_id': ObjectId('68518bd98498f7c04663a43b'), 'id': 51676, 'gender': 'Female', 'age': 61.0, 'hypertension': 0, 'heart_disease': 0, 'ever_married': 'Yes', 'work_type': 'Self-employed', 'Residence_type': 'Rural', 'avg_glucose_level': 202.21, 'bmi': nan, 'smoking_status': 'never smoked', 'stroke': 1}
# 2: {'_id': ObjectId('68518bd98498f7c04663a43c'), 'id': 31112, 'gender': 'Male', 'age': 80.0, 'hypertension': 0, 'heart_disease': 1, 'ever_married': 'Yes', 'work_type': 'Private', 'Residence_type': 'Rural', 'avg_glucose_level': 105.92, 'bmi': 32.5, 'smoking_status': 'never smoked', 'stroke': 1}
# ...
